# %% [markdown]
# # Benchmark of the clustering + smoothing method
#
# Our goal is to verify that our clustering and smoothing methods are working in a meaningful way. To measure this, we will take the CryptoBench test fold (set) and for each of the apo structures, we will check for existence of a cluster against the real cryptic binding site.
#
# To do so, we will need to:
# - predict the scores using the CryptoBench method
# - cluster the residues by given metrics
# - smoothen the clusters as in `smoothing/predict_single.ipynb`
# - compare the predicted and smoothened clusters with the actual cryptic binding sites
#
# Note that you will need to update the paths to the models and other data to run this notebook yourself.
# Also, using GPU is highly recommended.

# %%
### PREDICTION SOURCE CODE ###

import torch
from transformers import AutoTokenizer, EsmModel
import numpy as np
import torch.nn as nn
import os

ESM_MODEL_NAME = "facebook/esm2_t33_650M_UR50D"
MAX_LENGTH = 1024
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
OUTPUT_SIZE = 1
DROPOUT = 0.25
SEQUENCE_MAX_LENGTH = MAX_LENGTH - 2
# download: https://owncloud.cesnet.cz/index.php/s/mPo9NCWMBouwVAo/download
MODEL_PATH = "/home/polakluk/cryptobench-data/model/650M-model.pt"


class FinetuneESM(nn.Module):
    def __init__(self, esm_model: str) -> None:
        super().__init__()
        self.llm = EsmModel.from_pretrained(esm_model)
        self.dropout = nn.Dropout(DROPOUT)
        self.classifier = nn.Linear(self.llm.config.hidden_size, OUTPUT_SIZE)
        self.plDDT_regressor = nn.Linear(self.llm.config.hidden_size, OUTPUT_SIZE)
        self.distance_regressor = nn.Linear(self.llm.config.hidden_size, OUTPUT_SIZE)

    def forward(self, batch: dict[str, np.ndarray]) -> tuple[torch.Tensor, torch.Tensor, torch.Tensor]:
        input_ids, attention_mask = batch["input_ids"], batch["attention_mask"]
        token_embeddings = self.llm(input_ids=input_ids, attention_mask=attention_mask).last_hidden_state

        return (
            self.classifier(token_embeddings),
            self.plDDT_regressor(token_embeddings),
            self.distance_regressor(token_embeddings),
        )


def compute_prediction(sequence: str, emb_path: str) -> np.ndarray:
    """
    Compute the residue-level prediction using the CryptoBench model.

    Args:
        sequence (str): Sequence of amino acids to be predicted.

    Returns:
        np.ndarray: The predicted scores for each residue.
    """
    model = FinetuneESM(ESM_MODEL_NAME).to(DEVICE)
    model.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE), strict=True)

    tokenizer = AutoTokenizer.from_pretrained(ESM_MODEL_NAME)
    model.eval()

    KRAS_sequence = str(sequence)
    all_embeddings = []
    final_output = []

    # Process sequence in chunks of SEQUENCE_MAX_LENGTH
    for i in range(0, len(KRAS_sequence), SEQUENCE_MAX_LENGTH):
        processed_sequence = KRAS_sequence[i : i + SEQUENCE_MAX_LENGTH]

        tokenized = tokenizer(
            processed_sequence, max_length=MAX_LENGTH, padding="max_length", truncation=True, return_tensors="pt"
        )
        tokenized = {k: v.to(DEVICE) for k, v in tokenized.items()}

        # embeddings
        with torch.no_grad():
            llm_output = model.llm(input_ids=tokenized["input_ids"], attention_mask=tokenized["attention_mask"])
            embeddings = llm_output.last_hidden_state  # shape: (1, seq_len, hidden_dim)

        embeddings_np = embeddings.squeeze(0).detach().cpu().numpy()
        mask = tokenized["attention_mask"].squeeze(0).detach().cpu().numpy().astype(bool)
        embeddings_np = embeddings_np[mask][1:-1]  # exclude [CLS], [SEP]
        all_embeddings.append(embeddings_np)

        # prediction
        with torch.no_grad():
            output, _, _ = model(tokenized)

        output = output.squeeze(0)
        mask = tokenized["attention_mask"].squeeze(0).bool()
        output = output[mask][1:-1]  # exclude [CLS], [SEP]

        probabilities = torch.sigmoid(output).detach().cpu().numpy()
        final_output.extend(probabilities)

    # save the concatenated embeddings for the entire sequence
    final_embeddings = np.concatenate(all_embeddings, axis=0)
    save_path = os.path.join(emb_path)
    np.save(save_path, final_embeddings)

    return np.array(final_output).flatten()

# %%
### SMOOTHING SOURCE CODE ###

import torch
import numpy as np
import os

import torch.nn as nn

POSITIVE_DISTANCE_THRESHOLD = 15
NEGATIVE_DISTANCE_THRESHOLD = 10

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

def process_single_sequence(structure_name: str, chain_id: str, binding_residues: list[str], sequence: str, embedding_path: str, distance_matrix: np.ndarray):
    id = structure_name.lower() + chain_id
    if not os.path.exists(embedding_path):
        raise FileNotFoundError(f'Embedding file for {id} not found in {embedding_path}')
    
    embedding = np.load(embedding_path)

    Xs = []
    Ys = []
    idx = []

    binding_residues_indices = [int(residue[1:]) for residue in binding_residues]
    
    negative_examples_indices = set()
    
    for (aa, residue_idx) in [(residue[0], int(residue[1:])) for residue in binding_residues]:
        assert sequence[residue_idx] == aa
        close_residues_indices = np.where(distance_matrix[residue_idx] < POSITIVE_DISTANCE_THRESHOLD)[0]
        close_binding_residues_indices = np.intersect1d(close_residues_indices, binding_residues_indices)
        
        concatenated_embedding = np.concatenate((embedding[residue_idx], np.mean(embedding[close_binding_residues_indices], axis=0)))
        Xs.append(concatenated_embedding)
        Ys.append(1)  # positive example
        idx.append(residue_idx)
        
        really_close_residues_indices = np.where(distance_matrix[residue_idx] < NEGATIVE_DISTANCE_THRESHOLD)[0]
        negative_examples_indices.update(set(list(really_close_residues_indices)) - set(list(binding_residues_indices)))

    for residue_idx in negative_examples_indices:
        close_residues_indices = np.where(distance_matrix[residue_idx] < POSITIVE_DISTANCE_THRESHOLD)[0]
        close_binding_residues_indices = np.intersect1d(close_residues_indices, binding_residues_indices)
        concatenated_embedding = np.concatenate((embedding[residue_idx], np.mean(embedding[close_binding_residues_indices], axis=0)))
        Xs.append(concatenated_embedding)
        Ys.append(0)
        idx.append(residue_idx)

    return np.array(Xs), np.array(Ys), np.array(idx)

def predict_single_sequence(Xs, Ys, idx, model_3):
    Xs = torch.tensor(Xs, dtype=torch.float32).to(device)
    Ys = torch.tensor(Ys, dtype=torch.int64).to(device)
    idx = torch.tensor(idx, dtype=torch.int64).to(device)

    test_logits = model_3(Xs).squeeze()
    test_pred = torch.sigmoid(test_logits)

    return {'predictions': test_pred.detach().cpu().numpy(), 'indices': idx.detach().cpu().numpy()}

DECISION_THRESHOLD = 0.8
DROPOUT = 0.3
LAYER_WIDTH = 256
ESM2_DIM  = 1280 * 2

class CryptoBenchClassifier(nn.Module):
    def __init__(self, input_dim=ESM2_DIM):
        super().__init__()
        self.layer_1 = nn.Linear(in_features=input_dim, out_features=LAYER_WIDTH)
        self.dropout1 = nn.Dropout(DROPOUT)

        self.layer_2 = nn.Linear(in_features=LAYER_WIDTH, out_features=LAYER_WIDTH)
        self.dropout2 = nn.Dropout(DROPOUT)

        self.layer_3 = nn.Linear(in_features=LAYER_WIDTH, out_features=1)

        self.relu = nn.ReLU()

    def forward(self, x):
        # Intersperse the ReLU activation function between layers
        return self.layer_3(self.dropout2(self.relu(self.layer_2(self.dropout1(self.relu(self.layer_1(x)))))))

# %%
### UTILITIES ###

import requests
from Bio.PDB import PDBParser
from Bio.PDB.Polypeptide import is_aa
import io

d3to1 = {'CYS': 'C', 'ASP': 'D', 'SER': 'S', 'GLN': 'Q', 'LYS': 'K',
        'ILE': 'I', 'PRO': 'P', 'THR': 'T', 'PHE': 'F', 'ASN': 'N', 
        'GLY': 'G', 'HIS': 'H', 'LEU': 'L', 'ARG': 'R', 'TRP': 'W', 
        'ALA': 'A', 'VAL':'V', 'GLU': 'E', 'TYR': 'Y', 'MET': 'M'}

def compute_distance_matrix(coordinates: np.ndarray) -> np.ndarray:
    """
    Compute the pairwise distance matrix for a given set of coordinates.

    Args:
        coordinates (np.ndarray): A 2D array of shape (N, 3), where N is the number of points,
                                   and each row represents the (x, y, z) coordinates of a point.

    Returns:
        np.ndarray: A 2D array of shape (N, N), where the element at [i, j] represents the Euclidean
                    distance between the i-th and j-th points.
    """
    coordinates = np.array(coordinates)
    distance_matrix = np.linalg.norm(coordinates[:, np.newaxis] - coordinates[np.newaxis, :], axis=-1)
    return distance_matrix

def pockets_overlap(pocket1: tuple[str, ...], pocket2: tuple[str, ...]) -> bool:
    """
    Determine if two pockets overlap based on their residue sets.

    Args:
        pocket1 (tuple[str, ...]): A tuple of residue identifiers for the first pocket.
        pocket2 (tuple[str, ...]): A tuple of residue identifiers for the second pocket.

    Returns:
        bool: True if the overlap ratio between the two pockets is greater than 0.5, False otherwise.
    """
    set1 = set(pocket1)
    set2 = set(pocket2)
    intersection = set1.intersection(set2)
    overlap_ratio = len(intersection) / min(len(set1), len(set2))
    return overlap_ratio > 0.5

def download_pdb(pdb_id: str) -> str:
    """
    Download the PDB file content for a given PDB ID.

    Args:
        pdb_id (str): The PDB ID of the structure to download.

    Returns:
        str: The content of the PDB file as a string. Returns an empty string if the download fails.
    """
    url = f"https://files.rcsb.org/download/{pdb_id.upper()}.pdb"
    response = requests.get(url)
    if response.status_code != 200:
        return ""
    return response.text

def extract_sequence_and_ca_coords_and_ids(pdb_content: str, chain_id: str):
    """
    Extract the sequence, CA coordinates, and residue IDs for a specific chain from a PDB structure.

    Args:
        pdb_content (str): The content of the PDB file as a string.
        chain_id (str): The chain ID to extract data from.

    Returns:
        tuple: A tuple containing:
            - sequence (str): The amino acid sequence of the chain.
            - ca_coords (list): A list of (x, y, z) coordinates for the CA atoms.
            - residue_ids (list): A list of residue IDs corresponding to the sequence.

    Raises:
        ValueError: If the specified chain ID is not found in the structure.
    """
    parser = PDBParser(QUIET=True)
    structure = parser.get_structure("structure", io.StringIO(pdb_content))
    
    model = structure[0]  # Use first model
    if chain_id not in model:
        raise ValueError(f"Chain ID '{chain_id}' not found in structure.")
    
    chain = model[chain_id]

    # Extract sequence, CA coordinates, and residue ids, ensuring they are aligned by residue position
    seq = []
    ca_coords = []
    residue_ids = []
    for residue in chain:
        if is_aa(residue):
            resname = residue.get_resname()
            if "CA" in residue:
                seq.append(d3to1.get(resname, "X"))
                ca_coords.append(residue["CA"].get_coord())
                residue_ids.append(residue.get_id()[1])

    sequence = "".join(seq)
    return sequence, ca_coords, residue_ids

def compute_center_distance(points: np.ndarray, expected_pocket_ids: list[int], actual_pocket_ids: list[int]) -> float:
    """
    Compute the distance from the predicted pocket center to the expected pocket center.

    Args:
        points (np.ndarray): Array of shape (N, 3) containing the coordinates of the points.
        expected_pocket_ids (list[int]): List of indices corresponding to the expected pocket.
        actual_pocket_ids (list[int]): List of indices corresponding to the predicted pocket.
    Returns:
        float: The DCC value, which is the distance from the predicted pocket center to the ligand center.
    """
    expected_coords = points[expected_pocket_ids].mean(axis=0)
    actual_coords = points[actual_pocket_ids].mean(axis=0)

    dist = np.linalg.norm(expected_coords - actual_coords)
    return dist

# %%
### CLUSTERING SOURCE CODE ###

import numpy as np
import torch
from sklearn.cluster import DBSCAN

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# download: ../smoothing/pretrained_models/cryptobench_classifier.pt
MODEL_STATE_DICT_PATH = "/home/polakluk/cryptoshow-benchmark/smoothing/pretrained_models/cryptobench_classifier.pt"

def compute_clusters(
    points: list[list[float]],
    prediction_scores: list[float],
):
    """
    Compute clusters based on the given points and prediction scores.

    Args:
        points (list[list[float]]): A list of points, where each point is a list of 3 coordinates [x, y, z].
        prediction_scores (list[float]): A list of prediction scores corresponding to each point.

    Returns:
        np.ndarray: An array of cluster labels for each point. Points with no cluster are labeled as -1.
    """

    points_array = np.array(points)
    scores_array = np.array(prediction_scores).reshape(-1, 1)
    stacked = np.hstack((points_array, scores_array))  # Combine coordinates with scores

    HIGH_SCORE_THRESHOLD = 0.7  # Threshold to consider a point as high score

    high_score_mask = stacked[:, 3] > HIGH_SCORE_THRESHOLD
    high_score_points = stacked[high_score_mask][:, :3]  # Extract only (x, y, z) coordinates

    EPS = 5.0  # Max distance for neighbors
    MIN_SAMPLES = 3  # Min points to form a cluster

    # No pockets can be formed if there are not enough high score points.
    if len(high_score_points) < MIN_SAMPLES:
        return -1 * np.ones(len(points), dtype=int)

    dbscan = DBSCAN(eps=EPS, min_samples=MIN_SAMPLES)
    labels = dbscan.fit_predict(high_score_points)

    # Initialize all labels to -1
    all_labels = -1 * np.ones(len(points), dtype=int)
    # Assign cluster labels to high score points
    all_labels[high_score_mask] = labels
    labels = all_labels

    return labels

# %%
### MAIN SOURCE CODE ###

import os
import warnings
from transformers import logging as hf_logging
import matplotlib.pyplot as plt
import json
import seaborn as sns

# ignore some warnings from transformers...
warnings.filterwarnings("ignore")
hf_logging.set_verbosity_error()

# download: this folder
FOLD_FILE = "/home/polakluk/cryptoshow-benchmark/benchmark_experiments/test_fold_cb.json"

# open the FOLD_FILE and load the data
with open(FOLD_FILE, "r") as f:
    fold_data = json.load(f)

cryptic_pockets = {}

# for each item in fold_data, compute the clusters
for structure_name, items in fold_data.items():
    for record in items:
        key = f"{structure_name}_{record['apo_chain']}"
        # for simplicity, skip multi-spanning pockets (this would make many steps complicated)
        if "-" in record["apo_chain"]:
            continue
        value = tuple(record["apo_pocket_selection"])
        if key not in cryptic_pockets:
            cryptic_pockets[key] = []
        if value not in cryptic_pockets[key]:
            cryptic_pockets[key].append(value)

# merge pockets that overlap
merged_pockets = {}
for key, values in cryptic_pockets.items():
    merged = []
    for value in values:
        if not any(pockets_overlap(value, other) for other in merged):
            merged.append(value)
    merged_pockets[key] = merged

cryptic_pockets = merged_pockets

for key, values in list(cryptic_pockets.items())[:10]:
    print(f"{key}: {len(values)} unique pockets")
    for value in values:
        print(f"  - {value}")

os.makedirs("./tmp", exist_ok=True)

refined_clusters = {}
prediction_scores = {}
structure_ids = {}
structure_coords = {}

smoothing_model = CryptoBenchClassifier().to(DEVICE)
smoothing_model.load_state_dict(torch.load(MODEL_STATE_DICT_PATH, map_location=DEVICE), strict=True)

for structure in list(cryptic_pockets.keys()):
    structure_name, chain_id = structure.split("_")

    # get the structure sequence
    pdb_id = structure_name.lower()

    structure_content = download_pdb(pdb_id)
    if not structure_content:
        # remove the structure from the cryptic_pockets
        print(f"Structure {structure_name} not found. Skipping...")
        continue

    sequence, ca_coords, ids = extract_sequence_and_ca_coords_and_ids(structure_content, chain_id)
    print(f"Processing {structure_name} with chain {chain_id} and sequence length {len(sequence)}")

    assert len(ca_coords) == len(sequence), f"CA coordinates length {len(ca_coords)} does not match sequence length {len(sequence)}"
    assert len(ids) == len(sequence), f"Residue ids length {len(ids)} does not match sequence length {len(sequence)}"

    prediction = compute_prediction(sequence, f"./tmp/{structure_name}_{chain_id}.npy")
    assert len(prediction) == len(sequence), f"Prediction length {len(prediction)} does not match sequence length {len(sequence)}"

    clusters = compute_clusters(ca_coords, prediction)
    
    for cluster_label in np.unique(clusters):
        if cluster_label == -1:
            continue

        # DEBUG: Check the binding residues creation
        cryptic_pocket_flat = []
        for pocket in cryptic_pockets[structure]:
            for residue_str in pocket:
                # Extract residue number from the pocket selection format  
                if "_" in residue_str:
                    residue_num = int(residue_str.split("_")[1])
                    cryptic_pocket_flat.append(residue_num)
        
        binding_residues = []
        for residue_num in cryptic_pocket_flat:
            if residue_num in ids:
                seq_index = ids.index(residue_num)
                aa = sequence[seq_index]
                binding_residues.append(f"{aa}{seq_index}")
        
        if not binding_residues:
            print(f"No valid binding residues found for {structure}. Skipping...")
            continue

        single_for_prediction = process_single_sequence(
            structure_name=structure_name,
            chain_id=chain_id,
            binding_residues=binding_residues,
            sequence=sequence,
            embedding_path=f"./tmp/{structure_name}_{chain_id}.npy",
            distance_matrix=compute_distance_matrix(ca_coords)
        )

        if single_for_prediction[0].shape[0] == 0:
            print(f"Empty arrays returned from process_single_sequence. Skipping smoothing...")
            continue

        smoothened_prediction = predict_single_sequence(*single_for_prediction, model_3=smoothing_model)

        SMOOTHENED_THRESHOLD = 0.7 # this is defined by the training data - best F1 score was achieved with this threshold 

        selected_indices = np.where(smoothened_prediction['predictions'] > SMOOTHENED_THRESHOLD)[0]
        selected_indices_mapped = smoothened_prediction['indices'][selected_indices]

        for idx in selected_indices_mapped:
            clusters[idx] = cluster_label

    # get each of the clusters that is not -1 and save them
    refined_clusters[structure] = {}
    for cluster_id in np.unique(clusters):
        if cluster_id == -1:
            continue
        indices = np.where(clusters == cluster_id)[0]
        residues = [ids[i] for i in indices]
        refined_clusters[structure][cluster_id] = (residues, indices)

    prediction_scores[structure] = prediction
    structure_ids[structure] = ids
    structure_coords[structure] = ca_coords

dcc_values = []
dice_coefficients = []
residues_covered_percent = []
prediction_scores_list = []

for structure, cryptic_pocket_list in cryptic_pockets.items():
    if structure not in refined_clusters:
        continue

    ids = structure_ids[structure]
    unrefined = refined_clusters[structure]
    ca_coords = structure_coords[structure]

    for cryptic_pocket in cryptic_pocket_list:
        total_residues_covered = 0
        cryptic_pocket_residues = set([residue.split("_")[1] for residue in cryptic_pocket])

        best_dist = float('inf')
        best_dice = 0
        best_covered = 0

        for potential_pocket in unrefined.values():
            # potential_pocket is a tuple: (residues, indices)
            residues_tuple, indices_array = potential_pocket
            potential_pocket_str = set(str(r) for r in residues_tuple)
            residues_covered = len(potential_pocket_str & cryptic_pocket_residues)
            total_residues_covered += residues_covered

            assert len(residues_tuple) == len(indices_array), f"Residues and indices must have the same length, found {len(residues_tuple)} residues and {len(indices_array)} indices"
            assert len(prediction_scores[structure]) == len(ids), f"Prediction scores length {len(prediction_scores[structure])} does not match ids length {len(ids)}"

            expected_indices = [i for i, res_id in enumerate(ids) if str(res_id) in cryptic_pocket_residues]
            actual_indices = [i for i, res_id in enumerate(ids) if res_id in residues_tuple]

            if expected_indices:
                mean_score = np.mean([prediction_scores[structure][i] for i in expected_indices])
                prediction_scores_list.append(mean_score)

            if len(expected_indices) == 0 or len(actual_indices) == 0:
                continue

            dist = compute_center_distance(np.array(ca_coords), expected_indices, actual_indices)
            dice_coefficient = 2 * residues_covered / (len(cryptic_pocket_residues) + len(potential_pocket_str)) if (len(cryptic_pocket_residues) + len(potential_pocket_str)) > 0 else 0

            if dist < best_dist:
                best_dist = dist  
            if residues_covered > best_covered:
                best_covered = residues_covered
            if dice_coefficient > best_dice:
                best_dice = dice_coefficient

        percent_covered = best_covered / len(cryptic_pocket_residues) * 100 if cryptic_pocket_residues else 0
        # avoid the corner cases
        if np.isfinite(best_dist):
            dcc_values.append(best_dist)
        
            dice_coefficients.append(best_dice)
            residues_covered_percent.append(percent_covered)

sns.set_style("whitegrid")
plt.rcParams['figure.facecolor'] = 'white'

fig, axs = plt.subplots(1, 2, figsize=(16, 6))

sns.histplot(dcc_values, bins=20, color='skyblue', edgecolor='black', alpha=0.7, ax=axs[0])
axs[0].set_title(f'Pocket Center Distance Distribution\n(avg={np.mean(dcc_values):.2f} Å)', fontsize=12, fontweight='bold')
axs[0].set_xlabel('Pocket Center Distance (Å)', fontsize=11)
axs[0].set_ylabel('Count', fontsize=11)

sns.histplot(residues_covered_percent, bins=20, color='salmon', edgecolor='black', alpha=0.7, ax=axs[1])
axs[1].set_title(f'Residues Covered Percentage\n(avg={np.mean(residues_covered_percent):.1f}%)', fontsize=12, fontweight='bold')
axs[1].set_xlabel('Residues Covered (%)', fontsize=11)
axs[1].set_ylabel('Count', fontsize=11)

plt.tight_layout()
plt.show()

fig, axs = plt.subplots(1, 2, figsize=(16, 6))

sns.histplot(dice_coefficients, bins=20, color='mediumseagreen', edgecolor='black', alpha=0.7, ax=axs[0])
axs[0].set_title(f'Dice Coefficient Distribution\n(avg={np.mean(dice_coefficients):.2f})', fontsize=12, fontweight='bold')
axs[0].set_xlabel('Dice Coefficient', fontsize=11)
axs[0].set_ylabel('Count', fontsize=11)

sns.histplot(prediction_scores_list, bins=20, color='gold', edgecolor='black', alpha=0.7, ax=axs[1])
axs[1].axvline(0.7, color='red', linestyle='--', linewidth=2, label='Threshold = 0.7')
axs[1].set_title(f'Prediction Scores of Test Set CBSs\n(avg={np.mean(prediction_scores_list):.2f})', fontsize=12, fontweight='bold')
axs[1].set_xlabel('Prediction Score', fontsize=11)
axs[1].set_ylabel('Count', fontsize=11)
axs[1].legend(fontsize=10)

plt.tight_layout()
plt.show()
# Out:
# 7qoq_A: 1 unique pockets
#   - ('A_258', 'A_259', 'A_261', 'A_262', 'A_284', 'A_285', 'A_286', 'A_297', 'A_298', 'A_299')
# 8i84_B: 1 unique pockets
#   - ('B_26', 'B_27', 'B_28', 'B_29', 'B_30', 'B_31', 'B_33', 'B_35', 'B_40', 'B_73', 'B_93', 'B_94', 'B_95', 'B_189', 'B_210', 'B_211', 'B_213', 'B_214')
# 5igh_A: 1 unique pockets
#   - ('A_103', 'A_105', 'A_109', 'A_110', 'A_111', 'A_112', 'A_115', 'A_200', 'A_201', 'A_202', 'A_203', 'A_205', 'A_222', 'A_230', 'A_233', 'A_234', 'A_237', 'A_238', 'A_270', 'A_273', 'A_276', 'A_277', 'A_280', 'A_289')
# 7w19_A: 1 unique pockets
#   - ('A_24', 'A_26', 'A_27', 'A_28', 'A_29', 'A_30', 'A_32', 'A_34', 'A_44', 'A_46', 'A_88', 'A_90', 'A_91', 'A_93', 'A_94', 'A_95', 'A_98', 'A_194', 'A_198', 'A_199', 'A_201', 'A_212', 'A_213')
# 5uxa_A: 1 unique pockets
#   - ('A_27', 'A_29', 'A_30', 'A_31', 'A_32', 'A_33', 'A_35', 'A_37', 'A_47', 'A_49', 'A_92', 'A_94', 'A_95', 'A_97', 'A_98', 'A_99', 'A_204', 'A_205', 'A_207', 'A_218', 'A_219', 'A_221')
# 3h8a_B: 1 unique pockets
#   - ('B_38', 'B_39', 'B_40', 'B_41', 'B_158', 'B_166', 'B_167', 'B_208', 'B_245', 'B_289', 'B_316', 'B_339', 'B_341', 'B_368', 'B_369', 'B_370', 'B_371', 'B_392')
# 6isu_A: 1 unique pockets
#   - ('A_54', 'A_56', 'A_57', 'A_61', 'A_62', 'A_65', 'A_66', 'A_69', 'A_171', 'A_182', 'A_184', 'A_187', 'A_212', 'A_213', 'A_215', 'A_216', 'A_220', 'A_221', 'A_222', 'A_223')
# 5yhb_A: 1 unique pockets
#   - ('A_126', 'A_169', 'A_170', 'A_172', 'A_173')
# 3rwv_A: 1 unique pockets
#   - ('A_34', 'A_37', 'A_42', 'A_45', 'A_48', 'A_49', 'A_96', 'A_100', 'A_103', 'A_107', 'A_124', 'A_128', 'A_136', 'A_140', 'A_148', 'A_151', 'A_152', 'A_155')
# 2i3a_D: 1 unique pockets
#   - ('D_90', 'D_158', 'D_159', 'D_186', 'D_187', 'D_190', 'D_191', 'D_211', 'D_217', 'D_219', 'D_243')
# Processing 7qoq with chain A and sequence length 302
# Processing 8i84 with chain B and sequence length 285
# Processing 5igh with chain A and sequence length 301
# Processing 7w19 with chain A and sequence length 293
# Processing 5uxa with chain A and sequence length 301
# Processing 3h8a with chain B and sequence length 430
# Processing 6isu with chain A and sequence length 227
# Processing 5yhb with chain A and sequence length 178
# Processing 3rwv with chain A and sequence length 205
# Processing 2i3a with chain D and sequence length 347
# Processing 4oqo with chain B and sequence length 348
# Processing 3gdg with chain B and sequence length 267
# Processing 1kx9 with chain A and sequence length 108
# Processing 1kxr with chain A and sequence length 320
# Processing 1ute with chain A and sequence length 302
# Processing 7f4y with chain B and sequence length 901
# Processing 7nlx with chain A and sequence length 290
# Processing 1se8 with chain A and sequence length 213
# Processing 7xgf with chain E and sequence length 151
# Processing 5yj2 with chain C and sequence length 303
# Processing 7e5q with chain B and sequence length 352
# Processing 5e0v with chain A and sequence length 249
# Processing 6jq9 with chain B and sequence length 483
# Processing 7o1i with chain A and sequence length 726
# Processing 3ly8 with chain A and sequence length 323
# Processing 1bzj with chain A and sequence length 297
# Processing 7c63 with chain A and sequence length 416
# Processing 7x0i with chain B and sequence length 406
# Processing 5ysb with chain B and sequence length 385
# Processing 3k01 with chain A and sequence length 391
# Processing 5kcg with chain B and sequence length 397
# Processing 8b9p with chain A and sequence length 596
# Processing 3bjp with chain A and sequence length 295
# Processing 4uc8 with chain A and sequence length 223
# Processing 5b0e with chain B and sequence length 104
# Processing 5yqp with chain A and sequence length 185
# Processing 1nd7 with chain A and sequence length 374
# Processing 4fkm with chain B and sequence length 257
# Processing 2phz with chain A and sequence length 277
# Processing 3mwg with chain B and sequence length 274
# Processing 2vl2 with chain C and sequence length 161
# Processing 6bty with chain B and sequence length 128
# Processing 2fhz with chain B and sequence length 93
# Processing 5caz with chain A and sequence length 161
# Processing 3n4u with chain A and sequence length 301
# Processing 6fc2 with chain C and sequence length 177
# Processing 4hye with chain A and sequence length 200
# Processing 1i7n with chain A and sequence length 308
# Processing 1vsn with chain A and sequence length 215
# Processing 2d05 with chain A and sequence length 259
# Processing 1ksg with chain B and sequence length 128
# Processing 3flg with chain A and sequence length 135
# Processing 3t8b with chain A and sequence length 235
# Processing 4gpi with chain C and sequence length 235
# Processing 4gv9 with chain A and sequence length 198
# Processing 4kmy with chain A and sequence length 207
# Processing 4mwi with chain A and sequence length 266
# Processing 1lbe with chain B and sequence length 248
# Processing 1zm0 with chain A and sequence length 96
# Processing 4dnc with chain B and sequence length 268
# Processing 4ttp with chain A and sequence length 201
# Processing 5i3t with chain E and sequence length 363
# Processing 1arl with chain A and sequence length 307
# Processing 6cqe with chain B and sequence length 287
# Processing 2aka with chain A and sequence length 764
# Processing 3ugk with chain A and sequence length 372
# Processing 6eqj with chain A and sequence length 245
# Processing 1xtc with chain A and sequence length 192
# Processing 8aeq with chain A and sequence length 624
# Processing 2dfp with chain A and sequence length 534
# Processing 5tvi with chain V and sequence length 90
# Structure 7nbc not found. Skipping...
# Processing 2v6m with chain D and sequence length 303
# Processing 2rfj with chain B and sequence length 106
# Processing 7x0g with chain B and sequence length 287
# Processing 6vle with chain A and sequence length 460
# Processing 5acv with chain B and sequence length 233
# Processing 6g6y with chain A and sequence length 319
# Processing 5wbm with chain B and sequence length 302
# Processing 2i3r with chain A and sequence length 286
# Processing 7kay with chain A and sequence length 583
# Processing 7yjc with chain A and sequence length 381
# Processing 1dq2 with chain A and sequence length 224
# Processing 5tc0 with chain B and sequence length 250
# Processing 1pu5 with chain C and sequence length 161
# Processing 4jfr with chain C and sequence length 334
# Processing 9atc with chain A and sequence length 310
# Processing 3v55 with chain A and sequence length 368
# Processing 4bg8 with chain A and sequence length 314
# Processing 2zj7 with chain A and sequence length 616
# Processing 4qvk with chain B and sequence length 235
# Processing 2qbv with chain A and sequence length 73
# Processing 6a98 with chain C and sequence length 201
# Processing 2iyt with chain A and sequence length 175
# Processing 3st6 with chain C and sequence length 424
# Processing 1h13 with chain A and sequence length 404
# Processing 1m5w with chain D and sequence length 242
# Processing 2nt1 with chain B and sequence length 497
# Processing 1g59 with chain A and sequence length 468
# Processing 1p4v with chain A and sequence length 296
# Processing 5ey7 with chain B and sequence length 291
# Processing 2pkf with chain A and sequence length 332
# Processing 3idh with chain A and sequence length 453
# Processing 4jax with chain F and sequence length 460
# Processing 3w90 with chain A and sequence length 198
# Processing 2fem with chain A and sequence length 212
# Processing 2w8n with chain A and sequence length 480
# Processing 6o4f with chain H and sequence length 509
# Processing 6f52 with chain A and sequence length 233
# Processing 8gxj with chain C and sequence length 184
# Processing 5hij with chain A and sequence length 240
# Processing 2vqz with chain F and sequence length 160
# Processing 6fgj with chain B and sequence length 197
# Processing 1xgd with chain A and sequence length 315
# Processing 3uyi with chain A and sequence length 313
# Processing 4ikv with chain A and sequence length 492
# Processing 8j11 with chain X and sequence length 173
# Processing 8u3n with chain A and sequence length 377
# Processing 2h7s with chain A and sequence length 405
# Processing 4cmw with chain B and sequence length 286
# Processing 7v8k with chain B and sequence length 475
# Processing 4uum with chain A and sequence length 334
# Processing 1p4o with chain B and sequence length 314
# Processing 4ilg with chain A and sequence length 321
# Processing 8h27 with chain A and sequence length 181
# Processing 1cwq with chain A and sequence length 238
# Processing 5zj4 with chain D and sequence length 160
# Processing 2zcg with chain A and sequence length 318
# Processing 2x47 with chain A and sequence length 229
# Processing 1rtc with chain A and sequence length 268
# Processing 1p9o with chain A and sequence length 269
# Processing 7f2m with chain B and sequence length 323
# Processing 2vyr with chain A and sequence length 85
# Processing 3lnz with chain C and sequence length 82
# Processing 3lnz with chain O and sequence length 83
# Processing 4r0x with chain A and sequence length 122
# Processing 4nzv with chain B and sequence length 324
# Processing 3fzo with chain A and sequence length 262
# Processing 3nx1 with chain B and sequence length 165
# Processing 6tx0 with chain B and sequence length 479
# Processing 3vgm with chain A and sequence length 312
# Processing 8vxu with chain B and sequence length 104
# Processing 2pwz with chain G and sequence length 312
# Processing 5hto with chain E and sequence length 305
# Processing 5sc2 with chain A and sequence length 150
# Processing 1evy with chain A and sequence length 346
# Processing 8bre with chain B and sequence length 351
# Processing 4zoe with chain B and sequence length 724
# Processing 8aqi with chain B and sequence length 172
# Processing 1xjf with chain A and sequence length 619
# Processing 4rvt with chain B and sequence length 297
# Processing 7de1 with chain A and sequence length 108
# Processing 1x2g with chain C and sequence length 337
# Processing 4aem with chain A and sequence length 126
# Processing 7x0f with chain A and sequence length 446
# Processing 1g1m with chain B and sequence length 289
# Processing 6n5j with chain B and sequence length 301
# Processing 7c48 with chain A and sequence length 289
# Processing 1q4k with chain A and sequence length 222
# Processing 1uka with chain A and sequence length 271
# Processing 1xqv with chain A and sequence length 290
# Processing 3pfp with chain A and sequence length 464
# Processing 3pfp with chain B and sequence length 464
# Processing 7qzr with chain D and sequence length 464
# Processing 8ias with chain B and sequence length 501
# Processing 6ksc with chain A and sequence length 321
# Processing 4j4e with chain F and sequence length 101
# Processing 4zm7 with chain A and sequence length 180
# Processing 6du4 with chain A and sequence length 287
# Processing 3f4k with chain A and sequence length 254
# Processing 3a0x with chain A and sequence length 149
# Processing 4amv with chain B and sequence length 608
# Processing 7ndl with chain B and sequence length 655
# Processing 3tpo with chain A and sequence length 438
# Processing 1bk2 with chain A and sequence length 57
# Processing 1rjb with chain A and sequence length 298
# Processing 3pbf with chain A and sequence length 145
# Processing 3wb9 with chain C and sequence length 297
# Processing 5loc with chain A and sequence length 320
# Processing 1k47 with chain D and sequence length 322
# Processing 7nc8 with chain D and sequence length 237
# Processing 6hei with chain A and sequence length 346
# Processing 1e6k with chain A and sequence length 130
# Processing 4p2f with chain A and sequence length 189
# Processing 8onn with chain E and sequence length 268
# Processing 6w10 with chain A and sequence length 223
# Processing 3i8s with chain B and sequence length 261
# Processing 5z18 with chain C and sequence length 588
# Processing 4e1y with chain A and sequence length 353
# Processing 6nei with chain B and sequence length 339
# Processing 2xsa with chain A and sequence length 443
# Processing 5o8b with chain A and sequence length 243
# Processing 3jzg with chain A and sequence length 359
