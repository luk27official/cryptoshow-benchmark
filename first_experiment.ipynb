585, 0.051572322845458984, 0.17248624563217163, 0.26543182134628296, 0.04845677316188812, 0.08259417116641998, 0.1674858182668686, 0.13706529140472412, 0.18435080349445343, 0.16179035604000092, 0.2415628433227539, 0.8098605871200562, 0.43767687678337097, 0.8528589606285095, 0.6743787527084351, 0.8290385007858276, 0.6162224411964417, 0.5245566964149475, 0.039386067539453506, 0.04107782244682312, 0.05457737296819687, 0.08718055486679077, 0.034191809594631195, 0.11390406638383865, 0.20813962817192078, 0.09295430779457092, 0.06528642028570175, 0.059503693133592606, 0.03934044763445854, 0.19180434942245483, 0.07218796759843826, 0.1830904632806778, 0.1010359451174736, 0.7959546446800232, 0.2136392891407013, 0.4454507827758789, 0.8205454349517822, 0.41087430715560913, 0.031170658767223358, 0.04241633787751198, 0.08195742964744568, 0.07549471408128738, 0.0636509507894516, 0.055423203855752945, 0.23958230018615723, 0.06428279727697372, 0.2977138161659241, 0.1071438118815422, 0.02664419449865818, 0.14161281287670135, 0.07784751802682877, 0.02949107438325882, 0.02778044156730175, 0.02819492481648922, 0.1736486852169037, 0.08431180566549301, 0.16954658925533295, 0.2842094600200653, 0.1352166086435318, 0.36724647879600525, 0.411419540643692, 0.3597618639469147, 0.6326334476470947, 0.42843031883239746, 0.6174980998039246, 0.7042589783668518, 0.36773520708084106, 0.6499713063240051, 0.149581640958786, 0.38222283124923706, 0.5990737676620483, 0.22508542239665985, 0.06420218199491501, 0.7185726761817932, 0.38770827651023865, 0.13236674666404724, 0.47796472907066345, 0.6992219090461731, 0.2742922008037567, 0.04624219238758087, 0.03784932941198349, 0.1011294424533844, 0.11381403356790543, 0.041568852961063385, 0.06876609474420547, 0.12146280705928802, 0.026108449324965477, 0.18710066378116608, 0.10548918694257736, 0.06182150915265083, 0.07755383849143982, 0.035244252532720566, 0.1435808688402176, 0.06199580803513527, 0.21890036761760712, 0.22222061455249786, 0.170559823513031, 0.26510679721832275, 0.4161456823348999, 0.13636821508407593, 0.3712901473045349, 0.4808428883552551, 0.261157751083374, 0.24095483124256134, 0.3241496682167053, 0.2601151168346405, 0.3766331970691681, 0.2863464057445526, 0.2692420780658722, 0.460990846157074, 0.27233707904815674, 0.08879305422306061, 0.2611098289489746, 0.4419839680194855, 0.12945342063903809, 0.11677271127700806, 0.1868412345647812, 0.272427499294281, 0.23991186916828156, 0.24814610183238983, 0.25359854102134705, 0.35758665204048157]

TRUE_POCKET = [
    "A_258",
    "A_259",
    "A_261",
    "A_262",
    "A_284",
    "A_285",
    "A_286",
    "A_297",
    "A_298",
    "A_299"
]


# download the structure using biotite
cif_file_path: str = rcsb.fetch(STRUCTURE_ID, "cif")  # type: ignore

# read the structure
structure_file = pdbx.CIFFile.read(cif_file_path)
protein = pdbx.get_structure(structure_file, model=1)  # type: ignore
protein: AtomArray = protein[(protein.atom_name == "CA") & (protein.element == "C")]  # type: ignore

coordinates = []
for residue in protein:
    coordinates.append(residue.coord)

coordinates = [[float(c) for c in coord] for coord in coordinates]

assert len(PREDICTION) == len(coordinates), f"The length of the prediction and coordinates must be the same, but got {len(PREDICTION)} and {len(coordinates)}"

# compute the clusters
clusters = compute_clusters(coordinates, PREDICTION)
clusters = [int(p) for p in clusters]

# group residues into pockets
pocket_groups = {}
for i, pocket in enumerate(clusters):
    if pocket == -1:
        continue

    if pocket not in pocket_groups:
        pocket_groups[pocket] = {
            "pocket_id": pocket,
            "residue_ids": [],
            "prediction": [],
            "center": 0
        }
    pocket_groups[pocket]["residue_ids"].append(f"{protein[i].chain_id}_{protein[i].res_id}")
    pocket_groups[pocket]["prediction"].append(PREDICTION[i])

# compute the center of each pocket
for pocket in pocket_groups:
    # get the coordinates of the residues in the pocket
    pocket_coordinates = []
    for i, residue in enumerate(protein):
        if clusters[i] == pocket:
            pocket_coordinates.append(residue.coord)
    pocket_coordinates = [[float(c) for c in coord] for coord in pocket_coordinates]
    pocket_coordinates = [list(coord) for coord in zip(*pocket_coordinates)]
    pocket_groups[pocket]["center"] = [sum(coord) / len(pocket_coordinates) for coord in pocket_coordinates]
    pocket_groups[pocket]["center"] = [float(c) for c in pocket_groups[pocket]["center"]]

# get the coordinates of the true pocket
true_pocket_coordinates = []
for residue in protein:
    if f"{residue.chain_id}_{residue.res_id}" in TRUE_POCKET:
        true_pocket_coordinates.append(residue.coord)
true_pocket_coordinates = [[float(c) for c in coord] for coord in true_pocket_coordinates]
true_pocket_coordinates = [list(coord) for coord in zip(*true_pocket_coordinates)]
true_pocket_coordinates = [sum(coord) / len(true_pocket_coordinates) for coord in true_pocket_coordinates]
true_pocket_coordinates = [float(c) for c in true_pocket_coordinates]
print(f"True pocket coordinates: {true_pocket_coordinates}")

# for each pocket, calculate the DCC to the true pocket
for pocket in pocket_groups:
    pocket_coordinates = pocket_groups[pocket]["center"]
    dcc = 0
    for i in range(len(pocket_coordinates)):
        dcc += (pocket_coordinates[i] - true_pocket_coordinates[i]) ** 2
    dcc = dcc ** 0.5
    pocket_groups[pocket]["dcc"] = dcc

# print the pockets DCC
for pocket in pocket_groups:
    print(f"Pocket {pocket}: {pocket_groups[pocket]['dcc']}")
    print(f"Pocket {pocket}: {pocket_groups[pocket]['center']}")
    print(f"Pocket {pocket}: {pocket_groups[pocket]['residue_ids']}")
# Out:
# True pocket coordinates: [16.886096556981403, 15.634120240807533, -94.11214065551758]
# Pocket 0: 83.34791649160132
# Pocket 0: [21.84579372406006, 5.055643339951833, -11.587160110473633]
# Pocket 0: ['A_49', 'A_50', 'A_51', 'A_80']
# Pocket 1: 85.40747238423985
# Pocket 1: [22.37751038869222, -8.81332000096639, -12.462870121002197]
# Pocket 1: ['A_130', 'A_131', 'A_132', 'A_133']
# Pocket 2: 80.69898003914258
# Pocket 2: [14.922633171081543, -11.650083223978678, -18.190849622090656]
# Pocket 2: ['A_203', 'A_204', 'A_205']
# Pocket 3: 77.64852540798641
# Pocket 3: [-30.792919158935547, -36.99245643615723, -62.70436477661133]
# Pocket 3: ['B_49', 'B_50', 'B_51', 'B_78', 'B_80']
# Pocket 4: 68.51702550605927
# Pocket 4: [-24.585116704305012, -15.629969914754232, -49.421225229899086]
# Pocket 4: ['B_130', 'B_131', 'B_132', 'B_133']
# Pocket 5: 66.26002440183595
# Pocket 5: [-9.369133313496908, -6.701006730397542, -37.524192810058594]
# Pocket 5: ['B_203', 'B_204', 'B_205']
